# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({"Yes": [1,2,3], "No": [9,8,7]})
df
# Out:
#    Yes  No
# 0    1   9
# 1    2   8
# 2    3   7

# %%
df1 = pd.DataFrame({"Toygar": ["python", "pandas", "numpy"], "Taco": ["C", "DSA", "C#"]})
df1
# Out:
#    Toygar Taco
# 0  python    C
# 1  pandas  DSA
# 2   numpy   C#

# %%
ser = pd.Series([1,2,3,4,5])
ser
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
ser1 = pd.Series([30,40,50], index = ["2023 Sales", "2024 Sales", "2025 Sales"], name = "product A")

ser1
# Out:
# 2023 Sales    30
# 2024 Sales    40
# 2025 Sales    50
# Name: product A, dtype: int64

# %%
df = pd.read_csv("movies.csv", delimiter="|", on_bad_lines='skip')

df
# Out:
#     Color      James Cameron  723.0  178.0  760505847.0  \
# 0   Color     Gore Verbinski  302.0  169.0  309404152.0
# 1   Color         Sam Mendes  602.0  148.0  200074175.0
# 2   Color  Christopher Nolan  813.0  164.0  448130642.0
# 3       ?        Doug Walker      ?      ?            ?
# 4   Color     Andrew Stanton  462.0  132.0   73058679.0
# ..    ...                ...    ...    ...          ...
# 94  Color         James Gunn  653.0  121.0  333130696.0
# 95  Color  Christopher Nolan  712.0  169.0  187991439.0
# 96  Color  Christopher Nolan  642.0  148.0  292568851.0
# 97  Color       Hideaki Anno    1.0  120.0            ?
# 98  Color      Peter Jackson  645.0  182.0  303001229.0
#
#                                               Avatar   3054.0    USA  PG-13  \
# 0           Pirates of the Caribbean: At World's End   1238.0    USA  PG-13
# 1                                            Spectre    994.0     UK  PG-13
# ...

# %%
df.shape
# Out:
# (99, 13)

# %%
df.head()
# Out:
#    Color      James Cameron  723.0  178.0  760505847.0  \
# 0  Color     Gore Verbinski  302.0  169.0  309404152.0
# 1  Color         Sam Mendes  602.0  148.0  200074175.0
# 2  Color  Christopher Nolan  813.0  164.0  448130642.0
# 3      ?        Doug Walker      ?      ?            ?
# 4  Color     Andrew Stanton  462.0  132.0   73058679.0
#
#                                              Avatar   3054.0  USA  PG-13  \
# 0          Pirates of the Caribbean: At World's End   1238.0  USA  PG-13
# 1                                           Spectre    994.0   UK  PG-13
# 2                             The Dark Knight Rises   2701.0  USA  PG-13
# 3  Star Wars: Episode VII - The Force Awakens    ...       ?    ?      ?
# 4                                       John Carter    738.0  USA  PG-13
#
#    237,000,000.0  2009.0  7.9       Action
# 0  300,000,000.0  2007.0  7.1       Action
# 1  245,000,000.0  2015.0  6.8       Action
# 2  250,000,000.0  2012.0  8.5       Action
# ...

# %%
df.iloc[2]
# Out:
# Color                             Color
# James Cameron         Christopher Nolan
# 723.0                             813.0
# 178.0                             164.0
# 760505847.0                 448130642.0
# Avatar           The Dark Knight Rises
# 3054.0                           2701.0
# USA                                 USA
# PG-13                             PG-13
# 237,000,000.0             250,000,000.0
# 2009.0                           2012.0
# 7.9                                 8.5
# Action                           Action
# Name: 2, dtype: object

# %%
df.loc[2]
# Out:
# Color                             Color
# James Cameron         Christopher Nolan
# 723.0                             813.0
# 178.0                             164.0
# 760505847.0                 448130642.0
# Avatar           The Dark Knight Rises
# 3054.0                           2701.0
# USA                                 USA
# PG-13                             PG-13
# 237,000,000.0             250,000,000.0
# 2009.0                           2012.0
# 7.9                                 8.5
# Action                           Action
# Name: 2, dtype: object

# %%
df1 = pd.DataFrame({"Toygar": ["python", "pandas", "numpy"], "Taco": ["C", "DSA", "C#"]})
df1
# Out:
#    Toygar Taco
# 0  python    C
# 1  pandas  DSA
# 2   numpy   C#

# %%
df1["Buzz"] = ["A","B","C"]
df1
# Out:
#    Toygar Taco Buzz
# 0  python    C    A
# 1  pandas  DSA    B
# 2   numpy   C#    C

# %%
df1.drop(columns=["Buzz"])
# Out:
#    Toygar Taco
# 0  python    C
# 1  pandas  DSA
# 2   numpy   C#

# %%
df1.drop("Buzz", axis=1)
# Out:
#    Toygar Taco
# 0  python    C
# 1  pandas  DSA
# 2   numpy   C#

# %%
df1
# Out:
#    Toygar Taco Buzz
# 1  pandas  DSA    B
# 2   numpy   C#    C
# 3     NaN  NaN  NaN
